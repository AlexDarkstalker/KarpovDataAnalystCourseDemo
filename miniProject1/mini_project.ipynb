# %%
import pandas as pd

# %%
hotel_df = pd.read_csv('https://stepik.org/media/attachments/lesson/360344/bookings.csv', encoding='windows-1251', sep=";")

# %%
hotel_df.shape
# Out:
# (119390, 21)

# %%
hotel_df.dtypes.value_counts()
# Out:
# int64      10
# object     10
# float64     1
# dtype: int64

# %%
hotel_df.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_df.columns = hotel_df.columns.str.lower().str.replace(' ', '_')

# %%
hotel_df[hotel_df['is_canceled'] == 0] \
                                    .groupby('country') \
                                    .aggregate({'is_canceled': 'count'}) \
                                    .sort_values(by='is_canceled', ascending=False)
# Out:
#          is_canceled
# country
# PRT            21071
# GBR             9676
# FRA             8481
# ESP             6391
# DEU             6069
# ...              ...
# SMR                1
# MLI                1
# SLE                1
# MAC                1
# PLW                1
#
# [165 rows x 1 columns]

# %%
hotel_df.hotel.unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
hotel_df.groupby('hotel', as_index=False) \
        .aggregate({'stays_total_nights':'mean'}) \
        .style.format({'stays_total_nights': '{:.2f}'.format})
# Out:
# <style  type="text/css" >
# </style><table id="T_63409_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hotel</th>        <th class="col_heading level0 col1" >stays_total_nights</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63409_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_63409_row0_col0" class="data row0 col0" >City Hotel</td>
#                         <td id="T_63409_row0_col1" class="data row0 col1" >2.98</td>
#             </tr>
#             <tr>
#                         <th id="T_63409_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_63409_row1_col0" class="data row1 col0" >Resort Hotel</td>
#                         <td id="T_63409_row1_col1" class="data row1 col1" >4.32</td>
#             </tr>
#     </tbody></table>

# %%
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_df[hotel_df['reserved_room_type'] != hotel_df['assigned_room_type']].shape
# Out:
# (14917, 21)

# %%
hotel_df[hotel_df['arrival_date_year'] == 2016] \
                    .groupby('arrival_date_month') \
                    .aggregate({'hotel': 'count'}) \
                    .sort_values(by='hotel', ascending=False)
# Out:
#                     hotel
# arrival_date_month
# October              6203
# May                  5478
# April                5428
# September            5394
# June                 5292
# August               5063
# March                4824
# July                 4572
# November             4454
# February             3891
# December             3860
# January              2248

# %%
hotel_df[hotel_df['arrival_date_year'] == 2017] \
                    .groupby('arrival_date_month') \
                    .aggregate({'hotel': 'count'}) \
                    .sort_values(by='hotel', ascending=False)
# Out:
#                     hotel
# arrival_date_month
# May                  6313
# April                5661
# June                 5647
# July                 5313
# March                4970
# August               4925
# February             4177
# January              3681

# %%
hotel_df.groupby('arrival_date_year')['arrival_date_month'].value_counts()
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             5114
#                    October               4957
#                    August                3889
#                    December              2920
#                    July                  2776
#                    November              2340
# 2016               October               6203
#                    May                   5478
#                    April                 5428
#                    September             5394
#                    June                  5292
#                    August                5063
#                    March                 4824
#                    July                  4572
#                    November              4454
#                    February              3891
#                    December              3860
#                    January               2248
# 2017               May                   6313
#                    April                 5661
# ...

# %%
hotel_df[['adults', 'children', 'babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
hotel_df['total_kids'] = hotel_df.children + hotel_df.babies

# %%
hotel_df.groupby('hotel') \
        .aggregate({'total_kids': 'mean'}) \
        .style.format({'total_kids': '{:.2f}'.format})
# Out:
# <style  type="text/css" >
# </style><table id="T_a4034_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_kids</th>    </tr>    <tr>        <th class="index_name level0" >hotel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4034_level0_row0" class="row_heading level0 row0" >City Hotel</th>
#                         <td id="T_a4034_row0_col0" class="data row0 col0" >0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_a4034_level0_row1" class="row_heading level0 row1" >Resort Hotel</th>
#                         <td id="T_a4034_row1_col0" class="data row1 col0" >0.14</td>
#             </tr>
#     </tbody></table>

# %%
hotel_df['has_kids'] = hotel_df['total_kids'] > 0

# %%
hotel_df
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
(hotel_df.groupby('has_kids')['is_canceled'].value_counts(normalize=True) * 100).apply('{:.2f}'.format)
# Out:
# has_kids  is_canceled
# False     0              62.78
#           1              37.22
# True      0              65.08
#           1              34.92
# Name: is_canceled, dtype: object
